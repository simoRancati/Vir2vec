# %%
#############################
# Library Imports and Setup
#############################
from transformers import AutoModel, AutoModelForCausalLM, AutoTokenizer
import torch
import pandas as pd
import numpy as np
import os
import gc
import time
from torch.cuda.amp import autocast
import h5py
import sys
from torch.cuda import empty_cache

#############################
# Configuration Parameters
#############################
CSV_PATH = '/blue/salemi/share/varcovid/ViralLingo/Embedding/UseCases/Influence/NA.csv'
OUTPUT_DIR = '/blue/salemi/share/varcovid/ViralLingo/Embedding/UseCases/Influence/embeddings_results_NA'
CHUNK_SIZE = 50
BATCH_SIZE = 4
MAX_SEQUENCE_LENGTH = 4096
GRADIENT_CHECKPOINTING = True
USE_FP16 = False
POOLING_TYPE = 'max'  # *** Fixed to MAX pooling in this script ***

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'garbage_collection_threshold:0.8'

#############################
# Model Definitions
#############################

model_path = "/blue/simone.marini/share/Embeddings/Mistral422M/results/models/checkpoint-24752"
print("Exists? ", os.path.isdir(model_path))
print("Contents:", os.listdir(model_path))
MODELS = [
    {
        "name": "Local_Model",  # Custom locally trained model
        "model_path": "/blue/simone.marini/share/Embeddings/Mistral422M/results/models/checkpoint-24752",
        "model_class": AutoModelForCausalLM,  # Uses a model class for causal generation
        "tokenizer_class": AutoTokenizer,
        "trust_remote_code": True,  # Do not trust remote code execution by default
        "padding_side": "left", # Sequences will be padded on the left side
        "local_files_only" : True
    }
]

#############################
# Memory Management Helper
#############################

def clear_memory():
    if torch.cuda.is_available():
        empty_cache()
        torch.cuda.reset_peak_memory_stats()
    gc.collect()

#############################
# Batched Embedding Extraction (MAX pooling)
#############################

def get_embeddings_batched(model, tokenizer, sequence, Variant, batch_size=BATCH_SIZE):
    results = []
    total_batches = (len(sequence) + batch_size - 1) // batch_size

    for i in range(0, len(sequence), batch_size):
        print_first_batch = (i == 0)
        batch_sequence = sequence[i: i + batch_size]
        batch_Variant = Variant[i: i + batch_size]

        try:
            inputs = tokenizer(
                batch_sequence,
                padding=True,
                truncation=True,
                max_length=MAX_SEQUENCE_LENGTH,
                return_tensors='pt',
                return_overflowing_tokens=True,
                stride=512
            )

            for j in range(len(batch_sequence)):
                seq_embs = []

                if 'overflow_to_sample_mapping' in inputs:
                    seq_indices = [idx for idx, sample_idx in enumerate(inputs.overflow_to_sample_mapping) if sample_idx == j]
                else:
                    seq_indices = [j]

                for idx in seq_indices:
                    chunk_inputs = {
                        k: v[idx: idx + 1].to(model.device) if isinstance(v, torch.Tensor) else v
                        for k, v in inputs.items() if k != 'overflow_to_sample_mapping'
                    }
                    with torch.no_grad():
                        with autocast(enabled=USE_FP16):
                            output = model(**chunk_inputs)[0]
                            chunk_emb = torch.max(output, dim=1)[0]  # MAX pooling across tokens
                            seq_embs.append(chunk_emb.cpu())

                final_emb = torch.mean(torch.cat(seq_embs, dim=0), dim=0)
                numpy_emb = final_emb.numpy()


                results.append({
                    "Type": batch_Variant[j],
                    "Embedding": numpy_emb
                })

                del seq_embs, final_emb

            del inputs
            clear_memory()

        except Exception as e:
            print(f"Error processing batch {i // batch_size + 1}/{total_batches}: {e}")
            continue

        print(f"Processed batch {i // batch_size + 1}/{total_batches}")

    return results

#############################
# Save Embeddings Utility
#############################

def save_embeddings(embeddings, labels, filename):
    with h5py.File(filename, 'w') as f:
        emb_arr = np.vstack(embeddings)
        f.create_dataset('embeddings', data=emb_arr)
        dt = h5py.special_dtype(vlen=str)
        lab_ds = f.create_dataset('labels', (len(labels),), dtype=dt)
        lab_ds[:] = labels

#############################
# Model Processing Pipeline
#############################

def process_embeddings(model_info):
    clear_memory()
    model_name = model_info['name']
    print(f"\n=== Processing {model_name} with {POOLING_TYPE.upper()} pooling ===")

    embeddings_file = os.path.join(
        OUTPUT_DIR, f"{model_name}_{POOLING_TYPE}_embeddings.h5")

    if os.path.exists(embeddings_file):
        print("Embeddings file already exists – skipping computation.")
        return embeddings_file

    start_time = time.time()

    model = model_info['model_class'].from_pretrained(
        model_info['model_path'],
        trust_remote_code=model_info.get('trust_remote_code', True),
        local_files_only=True,
        torch_dtype=torch.float32,
        device_map={"": 0}
    )
    tokenizer = model_info['tokenizer_class'].from_pretrained(
        model_info['model_path'],
        trust_remote_code=model_info.get('trust_remote_code', False)
    )
    if 'padding_side' in model_info:
        tokenizer.padding_side = model_info['padding_side']

    if hasattr(model, 'gradient_checkpointing_enable') and GRADIENT_CHECKPOINTING:
        model.gradient_checkpointing_enable()
    if hasattr(model, 'config'):
        model.config.use_cache = False
    model.eval()

    all_embeddings, all_Variant = [], []
    total_rows = sum(1 for _ in open(CSV_PATH)) - 1
    rows_processed = 0

    for chunk_idx, chunk in enumerate(pd.read_csv(CSV_PATH, chunksize=CHUNK_SIZE)):
        if 'sequence' not in chunk.columns or 'source' not in chunk.columns:
            raise ValueError("CSV must contain 'sequence' and 'Variant' columns.")

        sequence = chunk['sequence'].tolist()
        Variant = chunk['source'].tolist()
        print(f"Processing chunk {chunk_idx + 1} containing {len(sequence)} sequence …")

        embeddings = get_embeddings_batched(model, tokenizer, sequence, Variant)

        for emb in embeddings:
            all_embeddings.append(emb["Embedding"])
            all_Variant.append(emb["Type"])
            rows_processed += 1                    # one sequence at a time
            if rows_processed % 100 == 0 or rows_processed == total_rows:
                progress = rows_processed / total_rows * 100
                print(f"Overall progress: {rows_processed}/{total_rows} rows ({progress:.2f}%)")
            
            # Save intermediate results every 5 chunks
            if (chunk_idx + 1) % 5 == 0:
                print("Saving intermediate results...")
                save_embeddings(all_embeddings, all_Variant, embeddings_file)

    save_embeddings(all_embeddings, all_Variant, embeddings_file)

    del model, tokenizer
    clear_memory()

    print(f"Finished {model_name} (max pooling) in {time.time() - start_time:.1f} s")
    return embeddings_file

#############################
# Main Entrypoint
#############################

def main():
    print("Starting DNA embedding extraction – MAX pooling mode")
    print(f"CSV: {CSV_PATH}\nOutput dir: {OUTPUT_DIR}")

    for model_info in MODELS:
        try:
            process_embeddings(model_info)
        except Exception as e:
            print(f"Failed to process {model_info['name']}: {e}")
        finally:
            clear_memory()

    print("All processing complete.")

if __name__ == '__main__':
    main()
# Out:
# Exists?  True
# Contents: ['scheduler.pt', 'trainer_state.json', 'model.safetensors', 'rng_state_1.pth', 'config.json', 'rng_state_0.pth', 'tokenizer.json', 'generation_config.json', 'training_args.bin', 'special_tokens_map.json', 'tokenizer_config.json', 'optimizer.pt']
# Starting DNA embedding extraction – MAX pooling mode
# CSV: /blue/salemi/share/varcovid/ViralLingo/Embedding/UseCases/Influence/NA.csv
# Output dir: /blue/salemi/share/varcovid/ViralLingo/Embedding/UseCases/Influence/embeddings_results_NA
#
# === Processing Local_Model with MAX pooling ===
# Processing chunk 1 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 2 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 100/11297 rows (0.89%)
# Processing chunk 3 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 4 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 200/11297 rows (1.77%)
# Processing chunk 5 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 6 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 300/11297 rows (2.66%)
# Processing chunk 7 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 8 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 400/11297 rows (3.54%)
# Processing chunk 9 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 10 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 500/11297 rows (4.43%)
# Saving intermediate results...
# Processing chunk 11 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 12 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 600/11297 rows (5.31%)
# Processing chunk 13 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 14 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 700/11297 rows (6.20%)
# Processing chunk 15 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 16 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 800/11297 rows (7.08%)
# Processing chunk 17 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 18 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 900/11297 rows (7.97%)
# Processing chunk 19 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 20 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 1000/11297 rows (8.85%)
# Saving intermediate results...
# Processing chunk 21 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 22 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1100/11297 rows (9.74%)
# Processing chunk 23 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 24 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1200/11297 rows (10.62%)
# Processing chunk 25 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 26 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1300/11297 rows (11.51%)
# Processing chunk 27 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 28 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1400/11297 rows (12.39%)
# Processing chunk 29 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 30 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 1500/11297 rows (13.28%)
# Saving intermediate results...
# Processing chunk 31 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 32 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1600/11297 rows (14.16%)
# Processing chunk 33 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 34 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1700/11297 rows (15.05%)
# Processing chunk 35 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 36 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1800/11297 rows (15.93%)
# Processing chunk 37 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 38 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 1900/11297 rows (16.82%)
# Processing chunk 39 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 40 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 2000/11297 rows (17.70%)
# Saving intermediate results...
# Processing chunk 41 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 42 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2100/11297 rows (18.59%)
# Processing chunk 43 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 44 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2200/11297 rows (19.47%)
# Processing chunk 45 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 46 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2300/11297 rows (20.36%)
# Processing chunk 47 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 48 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2400/11297 rows (21.24%)
# Processing chunk 49 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 50 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 2500/11297 rows (22.13%)
# Saving intermediate results...
# Processing chunk 51 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 52 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2600/11297 rows (23.01%)
# Processing chunk 53 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 54 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2700/11297 rows (23.90%)
# Processing chunk 55 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 56 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2800/11297 rows (24.79%)
# Processing chunk 57 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 58 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 2900/11297 rows (25.67%)
# Processing chunk 59 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 60 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 3000/11297 rows (26.56%)
# Saving intermediate results...
# Processing chunk 61 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 62 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 3100/11297 rows (27.44%)
# Processing chunk 63 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 64 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 3200/11297 rows (28.33%)
# Processing chunk 65 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 66 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 3300/11297 rows (29.21%)
# Processing chunk 67 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 68 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 3400/11297 rows (30.10%)
# Processing chunk 69 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 70 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 3500/11297 rows (30.98%)
# Saving intermediate results...
# Processing chunk 71 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 72 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 3600/11297 rows (31.87%)
# Processing chunk 73 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 74 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 3700/11297 rows (32.75%)
# Processing chunk 75 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# ...
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 204 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10200/11297 rows (90.29%)
# Processing chunk 205 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 206 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10300/11297 rows (91.17%)
# Processing chunk 207 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 208 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10400/11297 rows (92.06%)
# Processing chunk 209 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 210 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 10500/11297 rows (92.95%)
# Saving intermediate results...
# Processing chunk 211 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 212 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10600/11297 rows (93.83%)
# Processing chunk 213 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 214 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10700/11297 rows (94.72%)
# Processing chunk 215 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 216 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10800/11297 rows (95.60%)
# Processing chunk 217 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 218 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 10900/11297 rows (96.49%)
# Processing chunk 219 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 220 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Overall progress: 11000/11297 rows (97.37%)
# Saving intermediate results...
# Processing chunk 221 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 222 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 11100/11297 rows (98.26%)
# Processing chunk 223 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Processing chunk 224 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Overall progress: 11200/11297 rows (99.14%)
# Processing chunk 225 containing 50 sequence …
# Processed batch 1/13
# Processed batch 2/13
# Processed batch 3/13
# Processed batch 4/13
# Processed batch 5/13
# Processed batch 6/13
# Processed batch 7/13
# Processed batch 8/13
# Processed batch 9/13
# Processed batch 10/13
# Processed batch 11/13
# Processed batch 12/13
# Processed batch 13/13
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Saving intermediate results...
# Processing chunk 226 containing 47 sequence …
# Processed batch 1/12
# Processed batch 2/12
# Processed batch 3/12
# Processed batch 4/12
# Processed batch 5/12
# Processed batch 6/12
# Processed batch 7/12
# Processed batch 8/12
# Processed batch 9/12
# Processed batch 10/12
# Processed batch 11/12
# Processed batch 12/12
# Overall progress: 11297/11297 rows (100.00%)
# Finished Local_Model (max pooling) in 1565.7 s
# All processing complete.
